# %%
import marlo
import sys
import logging
logging.basicConfig(filename='myapp.log', level=logging.INFO)
logging.basicConfig(filename='myapp.log', level=logging.ERROR)

sys.path.append("../classes/")

from MinecraftEnvironmentManager import MinecraftEnvironmentManager

# %%
mem = MinecraftEnvironmentManager(marlo, 'test','MarLo-FindTheGoal-v0')
# Out:
# INFO:marlo.base_env_builder:params.gameMode : Cannot force survival mode.
# INFO:marlo.base_env_builder:params.gameMode : Cannot force survival mode.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
mem = MinecraftEnvironmentManager(marlo, 'test', 'MarLo-FindTheGoal-v0')
# Out:
# INFO:marlo.base_env_builder:params.gameMode : Cannot force survival mode.
# INFO:marlo.base_env_builder:params.gameMode : Cannot force survival mode.

# %%
mem.launch_enviroment()
# Out:
# Nothing is listening on port 10000 - will attempt to launch Minecraft from a new terminal.
# Giving Minecraft some time to launch...
# . . . . . . . . . . . . . . . . ok

# %%
mem.basic_run()
# Out:
# WARNING:marlo.base_env_builder:Error on attempting to start mission : A mission is already running.
# WARNING:marlo.base_env_builder:Will attempt again after 3 seconds.
# INFO:marlo.base_env_builder:Waiting for mission to start...
# INFO:marlo.base_env_builder:Mission Running
# reward: 0
# done: False
# info {}
# reward: -0.01
# done: False
# info {}
# reward: -0.01
# done: False
# info {}
# reward: 0
# done: False
# info {}
# reward: -0.03
# done: False
# info {}
# reward: 0
# done: False
# info {}
# reward: -0.01
# done: False
# info {}
# reward: -0.02
# done: False
# info {}
# reward: -0.01
# done: False
# info {}
# reward: 0
# done: False
# info {}
# reward: -0.02
# done: False
# info {}
# reward: -0.02
# done: False
# info {}
# reward: -0.01
# done: False
# info {}
# reward: -0.01
# done: False
# info {}
# reward: -0.02
# done: False
# info {}
# reward: -0.02
# done: False
# info {}
# reward: -0.01
# done: False
# info {}
# reward: -0.01
# done: False
# info {}
# reward: -0.01
# ...

# %%
mem.reset()
# Out:
# INFO:marlo.base_env_builder:Waiting for mission to start...
# INFO:marlo.base_env_builder:Mission Running

# %%
mem.num_actions_available()
# Out:
# 5

# %%
mem.get_screen_height()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8d1fb7cb3ffc> in <module>()
# ----> 1 mem.get_screen_height()
#
# C:\Users\danie\Documents\Uni\Masters-Dissertation\classes\MinecraftEnvironmentManager.py in get_screen_height(self)
#      71
#      72     def get_screen_height(self):
# ---> 73         screen = self.get_processed_screen()
#      74         return screen.shape[2]
#      75
#
# C:\Users\danie\Documents\Uni\Masters-Dissertation\classes\MinecraftEnvironmentManager.py in get_processed_screen(self)
#      81         screen = self.render('rgb_array').transpose((2, 0, 1)) # PyTorch expects CHW
#      82         screen = self.crop_screen(screen)
# ---> 83         return self.transform_screen_data(screen)
#      84
#      85     def crop_screen(self, screen):
#
# ...
