# %%
import minerl

minerl.data.download(directory="./dataset/")
# Out:
# WARNING:minerl.data.download:As of MineRL 0.3.0 automatic hash checking has been disabled.
#
# Download: https://minerl.s3.amazonaws.com/v3/data_texture_0_low_res.tar:   0%|          | 0/65075.77344 [00:00<?, ?MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ca20ea3fe267> in <module>
#       1 import minerl
#       2
# ----> 3 minerl.data.download(directory="./dataset/")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/minerl/data/download.py in download(directory, resolution, texture_pack, update_environment_variables, disable_cache, experiment, minimal)
#     100         dest_file = os.path.join(download_path, filename)
#     101         os.makedirs(os.path.dirname(dest_file), exist_ok=True)
# --> 102         download_with_resume(urls, dest_file)
#     103     except HTTPError as e:
# ...
