# %%
import matplotlib.pyplot as plt

import numpy as np

import pandas as pd

import pickle

import sys
sys.path.append("../functions")

from Utils import load_data

# %%
loss_path = '../resources/loss_2.sav'

# %%
loss = load_data(loss_path)

# %%
loss_df = pd.DataFrame(loss, columns=['loss1','loss2','loss3','loss4'])

# %%
plt.plot( loss_df['loss4'].values)
plt.plot( loss_df['loss3'].values)
plt.plot( loss_df['loss1'].values)
plt.plot( loss_df['loss2'].values)
plt.ylabel('some numbers')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
import matplotlib.pyplot as plt
plt.plot(scaler.fit(loss_df['loss1'].values.reshape(-1, 1)).transform(loss_df['loss1'].values.reshape(-1, 1)))
plt.plot( scaler.fit(loss_df['loss2'].values.reshape(-1, 1)).transform(loss_df['loss2'].values.reshape(-1, 1)))
plt.plot( scaler.fit(loss_df['loss3'].values.reshape(-1, 1)).transform(loss_df['loss3'].values.reshape(-1, 1)))
plt.plot( scaler.fit(loss_df['loss4'].values.reshape(-1, 1)).transform(loss_df['loss4'].values.reshape(-1, 1)))
plt.title('Losses')
plt.show()
